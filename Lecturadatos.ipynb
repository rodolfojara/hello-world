# %% [markdown]
# # 1 Prueba de lectura de datos y graficarlos

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure(figsize=(12, 10))
plt.xlabel('X coordinate')
plt.ylabel('Y coordinate')
plt.title('Ploteo de datos')

#data3 = ascii.read("./selfc.dat")
#x3 = data3['col2']
#y3 = data3['col3']
#plt.plot(x3,y3,'bo')

data1 = ascii.read("./selfa.dat")
x1 = data1['col2']
y1 = data1['col3']
plt.plot(x1,y1,'rs')

data2 = ascii.read("./selfb.dat")
x2 = data2['col2']
y2 = data2['col3']
plt.plot(x2,y2,'g+', markersize=16)

#print(data1) 

a=4.366142173e-02 
b=7.074846726e-01 
c=-7.073670562e-01 
d=7.763385459e-02 
e=7.080665130e-01 
f=7.068801461e-01 
sig=1.1385e-02 
Nr=18 
Nm=18 
sx=8.2483e-02 
sy=9.6745e-02

x12 = a + b*x1 + c*y1
y12 = d + e*x1 + f*y1

plt.plot(x12, y12, 'kd', markersize = 8)
